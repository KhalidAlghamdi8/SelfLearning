# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %%
#  url = 'https://www.goodreads.com/quotes?ref=nav_comm_quotes'
url = "https://www.goodreads.com/quotes?ref=nav_comm_quotes"
html_data = requests.get(url).text

# %%
html_data
# Out:
# '<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Popular Quotes</title>\n\n<meta content="Popular quotes from Goodreads members. Oscar Wilde: ‘Be yourself; everyone else is already taken.’, Marilyn Monroe: ‘I\'m selfish, impatient and a little ..." name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/quotes\' rel=\'canonical\'>\n\n\n\n  \n  <!-- * Copied from https://info.analytics.a2z.com/#/docs/data_collection/csa/onboard */ -->\n<script>\n  //<![CDATA[\n    !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n._s=r,this.csa=n}();\n    \n    if (window.csa) {\n      window.csa("Config", {\n        "Application": "GoodreadsMonolith",\n        "Events.SushiEndpoint": "https://unagi.amazon.com/1/events/com.amazon.csm.csa.prod",\n      
# ...

# %%
soup = BeautifulSoup(html_data,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="desktop withSiteHeaderTopFullImage">
# <head>
# <title>Popular Quotes</title>
# <meta content="Popular quotes from Goodreads members. Oscar Wilde: ‘Be yourself; everyone else is already taken.’, Marilyn Monroe: ‘I'm selfish, impatient and a little ..." name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://www.goodreads.com/quotes" rel="canonical"/>
# <!-- * Copied from https://info.analytics.a2z.com/#/docs/data_collection/csa/onboard */ -->
# <script>
#   //<![CDATA[
#     !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n._s=r,this.csa=n}();
#
#     if (window.csa) {
#       window.csa("Config", {
#         "Application": "GoodreadsMonolith",
#         "Events.SushiEndpoint": "https://unagi.amazon.com/1/events/com.amazon.csm.csa.prod",
# ...

# %%
import pandas as pd
data = pd.DataFrame(columns=["Quotes", "Author"])

for row in soup.find_all("div", {"class": ["quoteText" , "authorOrTitle"]}):
    # col = row.find_all('div')
    # if (col != []):
    #     quotes = col["class":"quoteText"].text.strip()
    #     author = col[2].text.strip()
    #     data = data.append({"Quotes":quotes, "Author": author}, ignore_index=True)
    # print(row.get('authorOrTitle'))
    print(row)
# Out:
# <div class="quoteText">
#       “Be yourself; everyone else is already taken.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Oscar Wilde
#   </span>
# </div>
# <div class="quoteText">
#       “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Marilyn Monroe
#   </span>
# </div>
# <div class="quoteText">
#       “Two things are infinite: the universe and human stupidity; and I'm not sure about the universe.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Albert Einstein
#   </span>
# </div>
# <div class="quoteText">
#       “So many books, so little time.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Frank Zappa
#   </span>
# </div>
# <div class="quoteText">
#       “A room without books is like a body without a soul.”
#   <br/>  ―
#   <span class="authorOrTitle">
# ...

# %%
data.head(5)
# Out:
# Empty DataFrame
# Columns: [Quotes, Author]
# Index: []

# %%
mydivs = soup.find_all("div", {"class": ["quoteText" , "authorOrTitle"]})
mydivs


df = pd.DataFrame(mydivs, columns =['quoteText','authorOrTitle']) 
df.head()
    # data = data.append({"Quotes":quotes, "Author": market_cap}, ignore_index=True)
    # print(row)
# Out:
# c:\Users\kalgh\anaconda3\envs\tf\lib\site-packages\pandas\core\internals\construction.py:576: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\kalgh\Desktop\self-learing\Web\goodreads.ipynb Cell 8 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kalgh/Desktop/self-learing/Web/goodreads.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> mydivs = soup.find_all("div", {"class": ["quoteText" , "authorOrTitle"]})
#       <a href='vscode-notebook-cell:/c%3A/Users/kalgh/Desktop/self-learing/Web/goodreads.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> mydivs
# ...

# %%
mydivs = soup.find_all("div", {"class": ["quoteText" , "authorOrTitle"]})

ls = []

for tags in mydivs:
    # tt = print(tags.text)
    data = ls.append(tags.text)

df = pd.DataFrame(data=ls)

print(df)
# Out:
#                                                     0
# 0   \n      “Be yourself; everyone else is already...
# 1   \n      “I'm selfish, impatient and a little i...
# 2   \n      “Two things are infinite: the universe...
# 3   \n      “So many books, so little time.”\n    ...
# 4   \n      “A room without books is like a body w...
# 5   \n      “Be who you are and say what you feel,...
# 6   \n      “You've gotta dance like there's nobod...
# 7   \n      “You know you're in love when you can'...
# 8   \n      “You only live once, but if you do it ...
# 9   \n      “Be the change that you wish to see in...
# 10  \n      “In three words I can sum up everythin...
# 11  \n      “If you want to know what a man's like...
# 12  \n      “Don’t walk in front of me… I may not ...
# 13  \n      “If you tell the truth, you don't have...
# 14  \n      “Friendship ... is born at the moment ...
# 15  \n      “I've learned that people will forget ...
# ...

# %%
url = "https://www.goodreads.com/quotes?ref=nav_comm_quotes"
from bs4 import BeautifulSoup as bs
ls = []
for page in range(1,100):

    req = requests.post(url + str(page) + '/')
    soup = bs(req.text, 'html.parser')

    mydivs = soup.find_all("div", {"class": ["quoteText" , "authorOrTitle"]})



    for i in range(1,100):
        if page > 1:
            for tags in mydivs:
                 data1 = ls.append(tags.text)
        else:
            for tags in mydivs:
                # tt = print(tags.text)
                data1 = ls.append(tags.text)

df = pd.DataFrame(data=ls)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
